# %% [markdown]
# <img src="data:image/png;base64,..." width=400 height=100/>
#
# ___
#
# * <b>Aluna Wang - Assistant Professor - HEC Paris</b>
# * <b>Tong Wang - Associate Professor - University of Edinburgh</b>
# * <b>Gaëtan Brison - ML Research Engineer - Institut Polytechnique de Paris</b>
# * <b>Awais Sani - ML Research Engineer - Télécom Paris</b>
# ___

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_final = pd.read_csv("df_final.csv")
df_final = df_final.drop_duplicates(subset=['Package_x','Final_List_Login_x'], keep='last').reset_index(drop=True)
display(df_final.head(3))
display(df_final.shape)
# Out:
#                             Package_x Final_List_Login_x            Login  \
# 0  https://github.com/mozilla/ichnaea           hannosch         hannosch
# 1  https://github.com/mozilla/ichnaea          jwhitlock        jwhitlock
# 2  https://github.com/mozilla/ichnaea    dependabot[bot]  dependabot[bot]
#
#            Id               Name    Company          Location  \
# 0    483109.0  Hanno Schlichting        NaN  Hamburg, Germany
# 1    286017.0      John Whitlock  @mozilla     Tulsa, OK, USA
# 2  49699333.0                NaN        NaN               NaN
#
#                Email                                                Bio  \
# 0  hanno@hannosch.eu                                                NaN
# 1                NaN  Developer at @mozilla working on Firefox Relay...
# 2                NaN                                                NaN
#
#    Public_Repos  Followers  Following           Created_at  \
# 0           4.0       97.0        0.0  2010-11-16 00:59:27
# ...

# %%
df_login_final = pd.read_csv("df_login_final.csv")
df_login_final = df_login_final.drop_duplicates(subset=['Package','Login_Unique'], keep='last').reset_index(drop=True)
display(df_login_final.head(3))
display(df_login_final.shape)
# Out:
#                               Package  \
# 0  https://github.com/mozilla/ichnaea
# 1  https://github.com/mozilla/ichnaea
# 2  https://github.com/mozilla/ichnaea
#
#                                                Login        Id  Contributions  \
# 0  ['hannosch', 'jwhitlock', 'dependabot[bot]', '...    483109           2777
# 1  ['hannosch', 'jwhitlock', 'dependabot[bot]', '...    286017            652
# 2  ['hannosch', 'jwhitlock', 'dependabot[bot]', '...  49699333            258
#
#    Count_Login     Login_Unique
# 0           30         hannosch
# 1           30        jwhitlock
# 2           30  dependabot[bot]
# (143287, 6)

# %%
df_final_contributor = pd.read_csv("df_final_contributor.csv")
df_final_contributor = df_final_contributor.drop_duplicates(subset=['Package_x','Final_List_Login_x'], keep='last').reset_index(drop=True)
display(df_final_contributor.head(3))
display(df_final_contributor.shape)
# Out:
#                             Package_x Final_List_Login_x            Login  \
# 0  https://github.com/mozilla/ichnaea           hannosch         hannosch
# 1  https://github.com/mozilla/ichnaea          jwhitlock        jwhitlock
# 2  https://github.com/mozilla/ichnaea    dependabot[bot]  dependabot[bot]
#
#            Id               Name    Company          Location  \
# 0    483109.0  Hanno Schlichting        NaN  Hamburg, Germany
# 1    286017.0      John Whitlock  @mozilla     Tulsa, OK, USA
# 2  49699333.0                NaN        NaN               NaN
#
#                Email                                                Bio  \
# 0  hanno@hannosch.eu                                                NaN
# 1                NaN  Developer at @mozilla working on Firefox Relay...
# 2                NaN                                                NaN
#
#    Public_Repos  Followers  Following           Created_at  \
# 0           4.0       97.0        0.0  2010-11-16 00:59:27
# ...

# %%
Final_Github_Step3 = pd.read_csv("Final_Github_Step3.csv")
Final_Github_Step3 = Final_Github_Step3.drop_duplicates(subset=['Package'], keep='last').reset_index(drop=True)
display(Final_Github_Step3.head(3))
display(Final_Github_Step3.shape)
# Out:
#    Index   Org_Name  Org_Stars                        Org_Url_Gitstar  \
# 0      0  microsoft    1878251  https://gitstar-ranking.com/microsoft
# 1      0  microsoft    1878251  https://gitstar-ranking.com/microsoft
# 2      0  microsoft    1878251  https://gitstar-ranking.com/microsoft
#
#    Org_Repo_Nbr                                      Org_Repo_Name  \
# 0          5004  ['vscode', 'terminal', 'TypeScript', 'PowerToy...
# 1          5004  ['vscode', 'terminal', 'TypeScript', 'PowerToy...
# 2          5004  ['vscode', 'terminal', 'TypeScript', 'PowerToy...
#
#                                       Org_Repo_Stars Org_Top_Repo  \
# 0  [135113, 84567, 83035, 76206, 56074, 40794, 40...       vscode
# 1  [135113, 84567, 83035, 76206, 56074, 40794, 40...       vscode
# 2  [135113, 84567, 83035, 76206, 56074, 40794, 40...       vscode
#
#           Org_Down_Repo  Org_Highest_Nbr_Stars  Org_Lowest_Nbr_Stars  \
# 0  TUTA_table_understan                 135113                     0
# ...

# %%
df_final3 = df_final.merge(df_login_final,left_on = ['Package_x','Login'],right_on= ['Package','Login_Unique'],how='left')
df_final4 = df_final3.merge(Final_Github_Step3,left_on = 'Package_x',right_on= 'Package',how='left')
# Out:
# /var/folders/v_/vcf1lg6d1d517lzpgs2wzyhr0000gn/T/ipykernel_1638/2393786651.py:2: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Package_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_final4 = df_final3.merge(Final_Github_Step3,left_on = 'Package_x',right_on= 'Package',how='left')

# %%
display(df_final4.head(30))
display(df_final4.shape)
# Out:
#                              Package_x        Final_List_Login_x  \
# 0   https://github.com/mozilla/ichnaea                  hannosch
# 1   https://github.com/mozilla/ichnaea                 jwhitlock
# 2   https://github.com/mozilla/ichnaea           dependabot[bot]
# 3   https://github.com/mozilla/ichnaea   dependabot-preview[bot]
# 4   https://github.com/mozilla/ichnaea               crankycoder
# 5   https://github.com/mozilla/ichnaea                    willkg
# 6   https://github.com/mozilla/ichnaea                   graydon
# 7   https://github.com/mozilla/ichnaea                  pyup-bot
# 8   https://github.com/mozilla/ichnaea                tarekziade
# 9   https://github.com/mozilla/ichnaea             jaredlockhart
# 10  https://github.com/mozilla/ichnaea                     almet
# 11  https://github.com/mozilla/ichnaea                  djmitche
# 12  https://github.com/mozilla/ichnaea                    lonnen
# ...

# %%
df_final5 = df_final4.loc[0:1000]

# %%
df_final5.shape
# Out:
# (1001, 53)

# %%
df_final5.to_excel("text.xlsx")

# %%
df_final4["Org_Name"] = [str(i).lower() for i in list(df_final4["Org_Name"])]
df_final4["Org_Name"] = [str(i).replace("@","") for i in list(df_final4["Org_Name"])]
df_final4["Company"] = [str(i).lower() for i in list(df_final4["Company"])]
df_final4["Company"] = [str(i).replace("@","") for i in list(df_final4["Company"])]

# %%
df_final6 = df_final4[["Org_Name","Company","Email"]]

# %%
df_final6.to_excel("test2.xlsx")

# %%
list_count_paid = []
for i in range(0,len(df_final4["Company"])):
    if str(df_final4["Company"][i]) != 'nan':
        if str(df_final4["Company"][i]) in str(df_final4["Org_Name"][i]):
            list_count_paid.append(1)
        else:
            list_count_paid.append(1)
    else:
        list_count_paid.append(0)

# %%
df_final4["Contributor_Paid_Status_Based_on_Company"] = list_count_paid

# %%
df_final4.head(3)
# Out:
#                             Package_x Final_List_Login_x          Login_x  \
# 0  https://github.com/mozilla/ichnaea           hannosch         hannosch
# 1  https://github.com/mozilla/ichnaea          jwhitlock        jwhitlock
# 2  https://github.com/mozilla/ichnaea    dependabot[bot]  dependabot[bot]
#
#          Id_x               Name   Company          Location  \
# 0    483109.0  Hanno Schlichting       nan  Hamburg, Germany
# 1    286017.0      John Whitlock  mozilla     Tulsa, OK, USA
# 2  49699333.0                NaN       nan               NaN
#
#                Email                                                Bio  \
# 0  hanno@hannosch.eu                                                NaN
# 1                NaN  Developer at @mozilla working on Firefox Relay...
# 2                NaN                                                NaN
#
#    Public_Repos  Followers  Following           Created_at  \
# 0           4.0       97.0        0.0  2010-11-16 00:59:27
# ...

# %%
len(list_count_paid)
# Out:
# 124754

# %%
list_domain = []
for i in range(0,len(df_final4["Company"])):
    if "@" in str(df_final4["Email"][i]):
        if "." in str(df_final4["Email"][i]):
            list_domain.append(str(df_final4["Email"][i]).split("@")[1].split(".")[0])
        else:
            list_domain.append("missing")
        
    else:
        list_domain.append("missing")

# %%
df_final4["Domain Email"] = list_domain

# %%
df_final4.head(3)
# Out:
#                             Package_x Final_List_Login_x          Login_x  \
# 0  https://github.com/mozilla/ichnaea           hannosch         hannosch
# 1  https://github.com/mozilla/ichnaea          jwhitlock        jwhitlock
# 2  https://github.com/mozilla/ichnaea    dependabot[bot]  dependabot[bot]
#
#          Id_x               Name   Company          Location  \
# 0    483109.0  Hanno Schlichting       nan  Hamburg, Germany
# 1    286017.0      John Whitlock  mozilla     Tulsa, OK, USA
# 2  49699333.0                NaN       nan               NaN
#
#                Email                                                Bio  \
# 0  hanno@hannosch.eu                                                NaN
# 1                NaN  Developer at @mozilla working on Firefox Relay...
# 2                NaN                                                NaN
#
#    Public_Repos  Followers  Following           Created_at  \
# 0           4.0       97.0        0.0  2010-11-16 00:59:27
# ...

# %%
df_final4["Domain Email"] = [str(i).lower() for i in list(df_final4["Domain Email"])]

# %%
list_count_email = []
for i in range(0,len(df_final4["Company"])):
    if str(df_final4["Domain Email"][i]) != 'missing':
        if str(df_final4["Domain Email"][i]) in str(df_final4["Org_Name"][i]):
            list_count_email.append(1)
        else:
            list_count_email.append(0)
    else:
        list_count_email.append(0)

# %%
str(df_final4["Domain Email"][0]) in str(df_final4["Org_Name"][0])
# Out:
# False

# %%
list_count_email = []

# %%
if str(df_final4["Domain Email"][0]) != 'missing' :
    if str(df_final4["Domain Email"][0]) in str(df_final4["Org_Name"][0]):
        list_count_email.append(1)

# %%
df_final4["Domain Email"][0]
# Out:
# 'hannosch'

# %%
list_count_email
# Out:
# []

# %%
df_final4["Contributor_Paid_Status_Based_on_Email"] = list_count_email

# %%
df_final4.head(3)
# Out:
#                             Package_x Final_List_Login_x          Login_x  \
# 0  https://github.com/mozilla/ichnaea           hannosch         hannosch
# 1  https://github.com/mozilla/ichnaea          jwhitlock        jwhitlock
# 2  https://github.com/mozilla/ichnaea    dependabot[bot]  dependabot[bot]
#
#          Id_x               Name   Company          Location  \
# 0    483109.0  Hanno Schlichting       nan  Hamburg, Germany
# 1    286017.0      John Whitlock  mozilla     Tulsa, OK, USA
# 2  49699333.0                NaN       nan               NaN
#
#                Email                                                Bio  \
# 0  hanno@hannosch.eu                                                NaN
# 1                NaN  Developer at @mozilla working on Firefox Relay...
# 2                NaN                                                NaN
#
#    Public_Repos  Followers  Following           Created_at  \
# 0           4.0       97.0        0.0  2010-11-16 00:59:27
# ...

# %%
df_final4.columns
# Out:
# Index(['Package_x', 'Final_List_Login_x', 'Login_x', 'Id_x', 'Name', 'Company',
#        'Location', 'Email', 'Bio', 'Public_Repos', 'Followers', 'Following',
#        'Created_at', 'Updated_at', 'Package_y', 'Final_List_Login_y',
#        'Package_x', 'Login_y', 'Id_y', 'Contributions', 'Count_Login',
#        'Login_Unique', 'Index', 'Org_Name', 'Org_Stars', 'Org_Url_Gitstar',
#        'Org_Repo_Nbr', 'Org_Repo_Name', 'Org_Repo_Stars', 'Org_Top_Repo',
#        'Org_Down_Repo', 'Org_Highest_Nbr_Stars', 'Org_Lowest_Nbr_Stars',
#        'Number of Pages', 'Python Repositories Github', 'Page Number Github',
#        'Page Number Github Url', 'List Repositories per Page',
#        'Number of Repositories per Page', 'Packages', 'Github',
#        'Url Repositories', 'Package_y', 'Languages', '% per Languages', 'Star',
#        'Issue', 'Fork', 'Pull', 'License',
#        'Top Contributor Featured on Main Page', 'Last Update Repository',
# ...

# %%
df_final4.head(3)
# Out:
#                             Package_x Final_List_Login_x          Login_x  \
# 0  https://github.com/mozilla/ichnaea           hannosch         hannosch
# 1  https://github.com/mozilla/ichnaea          jwhitlock        jwhitlock
# 2  https://github.com/mozilla/ichnaea    dependabot[bot]  dependabot[bot]
#
#          Id_x               Name   Company          Location  \
# 0    483109.0  Hanno Schlichting       nan  Hamburg, Germany
# 1    286017.0      John Whitlock  mozilla     Tulsa, OK, USA
# 2  49699333.0                NaN       nan               NaN
#
#                Email                                                Bio  \
# 0  hanno@hannosch.eu                                                NaN
# 1                NaN  Developer at @mozilla working on Firefox Relay...
# 2                NaN                                                NaN
#
#    Public_Repos  Followers  Following           Created_at  \
# 0           4.0       97.0        0.0  2010-11-16 00:59:27
# ...

# %%
df_final5 = df_final4[['Package_x', 'Final_List_Login_x', 'Id_x', 'Name', 'Company',
       'Location', 'Email', 'Bio', 'Public_Repos', 'Followers', 'Following',
       'Created_at', 'Updated_at',
       'Login_y', 'Contributions', 'Count_Login',
       'Login_Unique', 'Org_Name', 'Org_Stars', 'Org_Url_Gitstar',
       'Org_Repo_Nbr', 'Org_Repo_Name', 'Org_Repo_Stars', 'Org_Top_Repo',
       'Org_Down_Repo', 'Org_Highest_Nbr_Stars', 'Org_Lowest_Nbr_Stars',
       'Number of Pages', 'Python Repositories Github', 'Page Number Github',
       'Page Number Github Url', 'List Repositories per Page',
       'Number of Repositories per Page', 'Packages', 'Github',
       'Url Repositories', 'Languages', '% per Languages', 'Star',
       'Issue', 'Fork', 'Pull', 'License',
       'Top Contributor Featured on Main Page', 'Last Update Repository',
       'Total Number of Commits', 'Contributor_Paid_Status_Based_on_Company',
       'Domain Email', 'Contributor_Paid_Status_Based_on_Email']]

# %%
df_final6 = df_final5.rename(columns = {'Final_List_Login_x':'Contributor',
                                            'Id_x':'Contributor_Id',
                                            'Company':'Contributor_Company',
                                            'Location':'Contributor_Location',
                                            'Email':'Contributor_Email',
                                            'Bio':'Contributor_Bio',
                                            'Public_Repos':'Contributor_Nbr_of_Public_Repos',
                                            'Followers':'Contributor_Nbr_of_Followers',
                                            'Following':'Contributor_Nbr_of_Following',
                                            'Created At':'Contributor_Account_Creation',
                                            'Updated At':'Contributor_Account_Last_Update',
                                            'Org_Name':'Repository_Company',
                                            'Contributor_Paid_Status_Based_on_Company':'Contributor_Paid_Status_Based_on_Company',
                                            'Domain Email':'Contributor_Email_Domain',
                                            'Contributor_Paid_Status_Based_on_Email':'Contributor_Paid_Status_Based_on_Email',
                                            'Languages':'Repository_Languages',
                                            '% per Languages':'Repository_Percent_per_Languages',
                                            'Star':'Repository_Stars',
                                            'Issue':'Repository_Issues',
                                            'Fork':'Repository_Fork',
                                            'Pull':'Repository_Pull',
                                            'License':'Repository_License',
                                            'Top Contributor Featured on Main Page':'Repository_Top_Contributor_on_Main_Page',
                                            'Last Update Repository':'Repository_Last_Update',
                                            'Total Number of Commits':'Repository_Total_Nbr_Commits',
                                            'Login_y':'Repository_Contributors',                                      
})

# %%
df_final4.to_csv("Final_Github_Step4.csv")

# %%
len(df_final4["Company"])
# Out:
# 143287

# %%
df_final4["Domain Name"] = [str(i).split( for i in list(df_final4["Email"])]

# %%
for i in range

# %%
Email

# %%
df_final4.to_csv("Step4.csv",index=False)

# %%
df_final_v6 = df_final_v5[['Repository', 'Login', 'Id', 'Name', 'Company', 'Location', 'Email',
       'Bio', 'Public Repos', 'Followers', 'Following', 'Created At',
       'Updated At', 'Repository Company',
       'Contributor Paid on Repository based on Company', 'Domain Email',
       'Contributor Paid on Email based on Company', 'Stars', 'Commits_x',
       'PR', 'Contributions', 'Languages', '% per Languages',
       'Star', 'Issue', 'Fork', 'Pull', 'License', 'User', 'Repo Using',
       'Top Contributor Featured on Main Page', 'Last Update Repository',
       'Total Number of Commits', 'size', 'Created at', 'Project Id','Contributors', 'Commits_y']]

# %%
df_final5 = df_final4[['Package_x', 'Final_List_Login_x', 'Id_x', 'Name', 'Company',
       'Location', 'Email', 'Bio', 'Public_Repos', 'Followers', 'Following',
       'Created_at', 'Updated_at',
       'Login_y', 'Contributions', 'Count_Login',
       'Login_Unique', 'Org_Name', 'Org_Stars', 'Org_Url_Gitstar',
       'Org_Repo_Nbr', 'Org_Repo_Name', 'Org_Repo_Stars', 'Org_Top_Repo',
       'Org_Down_Repo', 'Org_Highest_Nbr_Stars', 'Org_Lowest_Nbr_Stars',
       'Number of Pages', 'Python Repositories Github', 'Page Number Github',
       'Page Number Github Url', 'List Repositories per Page',
       'Number of Repositories per Page', 'Packages', 'Github',
       'Url Repositories', 'Languages', '% per Languages', 'Star',
       'Issue', 'Fork', 'Pull', 'License',
       'Top Contributor Featured on Main Page', 'Last Update Repository',
       'Total Number of Commits', 'Contributor_Paid_Status_Based_on_Company',
       'Domain Email', 'Contributor_Paid_Status_Based_on_Email']]

# %%
df_final6 = df_final5.rename(columns = {'Login':'Contributor',
                                            'Id':'Contributor_Id',
                                            'Company':'Contributor_Company',
                                            'Location':'Contributor_Location',
                                            'Email':'Contributor_Email',
                                            'Bio':'Contributor_Bio',
                                            'Public Repos':'Contributor_Nbr_of_Public_Repos',
                                            'Followers':'Contributor_Nbr_of_Followers',
                                            'Following':'Contributor_Nbr_of_Following',
                                            'Created At':'Contributor_Account_Creation',
                                            'Updated At':'Contributor_Account_Last_Update',
                                            'Repository Company':'Repository_Company',
                                            'Contributor Paid on Repository based on Company':'Contributor_Paid_Status_Based_on_Company',
                                            'Domain Email':'Contributor_Email_Domain',
                                            'Contributor Paid on Email based on Company':'Contributor_Paid_Status_Based_on_Email',
                                            'Stars':'Contributor_Stars',
                                            'Commits_x':'Contributor_Commits_All_Repositories_2022',
                                            'PR':'Contributor_PR_All_Repositories_2022',
                                            'Contributions':'Contributor_Contributions_All_Repositories_2022',
                                            'Languages':'Repository_Languages',
                                            '% per Languages':'Repository_Percent_per_Languages',
                                            'Star':'Repository_Stars',
                                            'Issue':'Repository_Issues',
                                            'Fork':'Repository_Fork',
                                            'Pull':'Repository_Pull',
                                            'License':'Repository_License',
                                            'User':'Repository_User',
                                            'Repo Using':'Repository_using_other_Repository',
                                            'Top Contributor Featured on Main Page':'Repository_Top_Contributor_on_Main_Page',
                                            'Last Update Repository':'Repository_Last_Update',
                                            'Total Number of Commits':'Repository_Total_Nbr_Commits',
                                            'size':'Repository_Size',
                                            'Created at':'Repository_Created_at',
                                            'Project Id':'Repository_Project_Id',
                                            'Contributors':'Repository_Contributors',
                                            'Commits_y':'Repository_Top_Commits_Graph',                                            
})

# %%
df_final6.head(3)
# Out:
#                             Package_x                           Package_x  \
# 0  https://github.com/mozilla/ichnaea  https://github.com/mozilla/ichnaea
# 1  https://github.com/mozilla/ichnaea  https://github.com/mozilla/ichnaea
# 2  https://github.com/mozilla/ichnaea  https://github.com/mozilla/ichnaea
#
#        Contributor  Contributor_Id               Name Contributor_Company  \
# 0         hannosch        483109.0  Hanno Schlichting                 nan
# 1        jwhitlock        286017.0      John Whitlock            mozilla
# 2  dependabot[bot]      49699333.0                NaN                 nan
#
#   Contributor_Location  Contributor_Email  \
# 0     Hamburg, Germany  hanno@hannosch.eu
# 1       Tulsa, OK, USA                NaN
# 2                  NaN                NaN
#
#                                      Contributor_Bio  \
# 0                                                NaN
# 1  Developer at @mozilla working on Firefox Relay...
# ...

# %%
df_final6.columns
# Out:
# Index(['Package_x', 'Package_x', 'Contributor', 'Contributor_Id', 'Name',
#        'Contributor_Company', 'Contributor_Location', 'Contributor_Email',
#        'Contributor_Bio', 'Contributor_Nbr_of_Public_Repos',
#        'Contributor_Nbr_of_Followers', 'Contributor_Nbr_of_Following',
#        'Created_at', 'Updated_at', 'Repository_Contributors', 'Contributions',
#        'Count_Login', 'Login_Unique', 'Repository_Company', 'Org_Stars',
#        'Org_Url_Gitstar', 'Org_Repo_Nbr', 'Org_Repo_Name', 'Org_Repo_Stars',
#        'Org_Top_Repo', 'Org_Down_Repo', 'Org_Highest_Nbr_Stars',
#        'Org_Lowest_Nbr_Stars', 'Number of Pages', 'Python Repositories Github',
#        'Page Number Github', 'Page Number Github Url',
#        'List Repositories per Page', 'Number of Repositories per Page',
#        'Packages', 'Github', 'Url Repositories', 'Repository_Languages',
#        'Repository_Percent_per_Languages', 'Repository_Stars',
# ...

# %%
df_final7 = df_final6[[ 'Contributor', 'Contributor_Id', 'Name',
       'Contributor_Company', 'Contributor_Location', 'Contributor_Email',
       'Contributor_Bio', 'Contributor_Nbr_of_Public_Repos',
       'Contributor_Nbr_of_Followers', 'Contributor_Nbr_of_Following',
       'Created_at', 'Updated_at', 'Repository_Contributors', 'Contributions',
       'Count_Login', 'Repository_Company', 'Org_Stars',
       'Org_Url_Gitstar', 'Org_Repo_Nbr', 'Org_Repo_Name', 'Org_Repo_Stars',
       'Org_Top_Repo', 'Org_Down_Repo', 'Org_Highest_Nbr_Stars',
       'Org_Lowest_Nbr_Stars', 'Number of Pages',
       'List Repositories per Page', 'Number of Repositories per Page',
       'Packages', 'Github', 'Url Repositories', 'Repository_Languages',
       'Repository_Percent_per_Languages', 'Repository_Stars',
       'Repository_Issues', 'Repository_Fork', 'Repository_Pull',
       'Repository_License', 'Repository_Top_Contributor_on_Main_Page',
       'Repository_Last_Update', 'Repository_Total_Nbr_Commits',
       'Contributor_Paid_Status_Based_on_Company', 'Contributor_Email_Domain',
       'Contributor_Paid_Status_Based_on_Email']]

# %%
df_final8 = df_final7.rename(columns = {'Name':'Contributor_Name',
                                            'Created_at':'Contributor_Created_at',
                                            'Updated_at':'Contributor_Updated_at',
                                            'Count_Login':'Repository_Nbr_Contributor_Taken_Into_Account',
                                            'List Repositories per Page':'Org_Repo_Per_Page',
                                            'Packages':'Repository_Name',
                                            'Number of Repositories per Page':'Org_Page_Nbr_Repo',
                                            'Github':'Org_Url',
                                            'Url Repositories':'Repository_Url',
                                            'Number of Pages':'Org_Nbr_Pages_Python',
                                                      
})

# %%
df_final9.columns
# Out:
# Index(['Contributor', 'Contributor_Id', 'Contributor_Name',
#        'Contributor_Company', 'Contributor_Location', 'Contributor_Email',
#        'Contributor_Bio', 'Contributor_Nbr_of_Public_Repos',
#        'Contributor_Nbr_of_Followers', 'Contributor_Nbr_of_Following',
#        'Contributor_Created_at', 'Contributor_Updated_at',
#        'Repository_Contributors', 'Contributions',
#        'Repository_Nbr_Contributor_Taken_Into_Account', 'Org_Name',
#        'Org_Stars', 'Org_Url_Gitstar', 'Org_Repo_Nbr', 'Org_Repo_Name',
#        'Org_Repo_Stars', 'Org_Top_Repo', 'Org_Down_Repo',
#        'Org_Highest_Nbr_Stars', 'Org_Lowest_Nbr_Stars', 'Org_Nbr_Pages_Python',
#        'Org_Repo_Per_Page', 'Org_Page_Nbr_Repo', 'Repository_Name', 'Org_Url',
#        'Repository_Url', 'Repository_Languages',
#        'Repository_Percent_per_Languages', 'Repository_Stars',
#        'Repository_Issues', 'Repository_Fork', 'Repository_Pull',
# ...

# %%
df_final10 = df_final9[['Org_Name','Org_Url','Org_Stars', 'Org_Url_Gitstar', 'Org_Repo_Nbr', 'Org_Repo_Name',
       'Org_Repo_Stars', 'Org_Top_Repo', 'Org_Down_Repo',
       'Org_Highest_Nbr_Stars', 'Org_Lowest_Nbr_Stars', 'Org_Nbr_Pages_Python',
       'Org_Repo_Per_Page', 'Org_Page_Nbr_Repo','Repository_Name',
       'Repository_Url', 'Repository_Languages',
       'Repository_Percent_per_Languages', 'Repository_Stars',
       'Repository_Issues', 'Repository_Fork', 'Repository_Pull',
       'Repository_License', 'Repository_Top_Contributor_on_Main_Page',
       'Repository_Last_Update', 'Repository_Total_Nbr_Commits','Repository_Contributors','Repository_Nbr_Contributor_Taken_Into_Account',
        'Contributor', 'Contributor_Id', 'Contributor_Name',
       'Contributor_Company', 'Contributor_Location', 'Contributor_Email',
       'Contributor_Bio', 'Contributor_Nbr_of_Public_Repos',
       'Contributor_Nbr_of_Followers', 'Contributor_Nbr_of_Following',
       'Contributor_Created_at', 'Contributor_Updated_at']]

# %%
df_final10.head(3)
# Out:
#   Org_Name                     Org_Url  Org_Stars  \
# 0  mozilla  https://github.com/mozilla     250005
# 1  mozilla  https://github.com/mozilla     250005
# 2  mozilla  https://github.com/mozilla     250005
#
#                        Org_Url_Gitstar  Org_Repo_Nbr  \
# 0  https://gitstar-ranking.com/mozilla          2331
# 1  https://gitstar-ranking.com/mozilla          2331
# 2  https://gitstar-ranking.com/mozilla          2331
#
#                                        Org_Repo_Name  \
# 0  ['pdf.js', 'DeepSpeech', 'send', 'sops', 'Brow...
# 1  ['pdf.js', 'DeepSpeech', 'send', 'sops', 'Brow...
# 2  ['pdf.js', 'DeepSpeech', 'send', 'sops', 'Brow...
#
#                                       Org_Repo_Stars Org_Top_Repo  \
# 0  [39606, 20047, 13166, 10470, 8919, 7834, 6145,...       pdf.js
# 1  [39606, 20047, 13166, 10470, 8919, 7834, 6145,...       pdf.js
# 2  [39606, 20047, 13166, 10470, 8919, 7834, 6145,...       pdf.js
#
# ...

# %%
df_final10.head(3)
# Out:
#   Org_Name                     Org_Url  Org_Stars  \
# 0  mozilla  https://github.com/mozilla     250005
# 1  mozilla  https://github.com/mozilla     250005
# 2  mozilla  https://github.com/mozilla     250005
#
#                        Org_Url_Gitstar  Org_Repo_Nbr  \
# 0  https://gitstar-ranking.com/mozilla          2331
# 1  https://gitstar-ranking.com/mozilla          2331
# 2  https://gitstar-ranking.com/mozilla          2331
#
#                                        Org_Repo_Name  \
# 0  ['pdf.js', 'DeepSpeech', 'send', 'sops', 'Brow...
# 1  ['pdf.js', 'DeepSpeech', 'send', 'sops', 'Brow...
# 2  ['pdf.js', 'DeepSpeech', 'send', 'sops', 'Brow...
#
#                                       Org_Repo_Stars Org_Top_Repo  \
# 0  [39606, 20047, 13166, 10470, 8919, 7834, 6145,...       pdf.js
# 1  [39606, 20047, 13166, 10470, 8919, 7834, 6145,...       pdf.js
# 2  [39606, 20047, 13166, 10470, 8919, 7834, 6145,...       pdf.js
#
# ...

# %%
df_final10.shape
# Out:
# (143287, 43)

# %%
df_final10.to_csv("Final_Github_Step4.csv",index=False)

# %%
df_final9 = df_final8.iloc[: , 1:]

# %%
df_final9 = df_final8.rename(columns = {'Repository_Company':'Org_Name',

                                                      
})

# %%
df_final9.head(3)
# Out:
#        Contributor  Contributor_Id   Contributor_Name Contributor_Company  \
# 0         hannosch        483109.0  Hanno Schlichting                 nan
# 1        jwhitlock        286017.0      John Whitlock            mozilla
# 2  dependabot[bot]      49699333.0                NaN                 nan
#
#   Contributor_Location  Contributor_Email  \
# 0     Hamburg, Germany  hanno@hannosch.eu
# 1       Tulsa, OK, USA                NaN
# 2                  NaN                NaN
#
#                                      Contributor_Bio  \
# 0                                                NaN
# 1  Developer at @mozilla working on Firefox Relay...
# 2                                                NaN
#
#    Contributor_Nbr_of_Public_Repos  Contributor_Nbr_of_Followers  \
# 0                              4.0                          97.0
# 1                            115.0                         211.0
# 2                              0.0                           0.0
#
# ...

# %%
df_final_v7 = df_final_v6.rename(columns = {'Login':'Contributor',
                                            'Id':'Contributor_Id',
                                            'Company':'Contributor_Company',
                                            'Location':'Contributor_Location',
                                            'Email':'Contributor_Email',
                                            'Bio':'Contributor_Bio',
                                            'Public Repos':'Contributor_Nbr_of_Public_Repos',
                                            'Followers':'Contributor_Nbr_of_Followers',
                                            'Following':'Contributor_Nbr_of_Following',
                                            'Created At':'Contributor_Account_Creation',
                                            'Updated At':'Contributor_Account_Last_Update',
                                            'Repository Company':'Repository_Company',
                                            'Contributor Paid on Repository based on Company':'Contributor_Paid_Status_Based_on_Company',
                                            'Domain Email':'Contributor_Email_Domain',
                                            'Contributor Paid on Email based on Company':'Contributor_Paid_Status_Based_on_Email',
                                            'Stars':'Contributor_Stars',
                                            'Commits_x':'Contributor_Commits_All_Repositories_2022',
                                            'PR':'Contributor_PR_All_Repositories_2022',
                                            'Contributions':'Contributor_Contributions_All_Repositories_2022',
                                            'Languages':'Repository_Languages',
                                            '% per Languages':'Repository_Percent_per_Languages',
                                            'Star':'Repository_Stars',
                                            'Issue':'Repository_Issues',
                                            'Fork':'Repository_Fork',
                                            'Pull':'Repository_Pull',
                                            'License':'Repository_License',
                                            'User':'Repository_User',
                                            'Repo Using':'Repository_using_other_Repository',
                                            'Top Contributor Featured on Main Page':'Repository_Top_Contributor_on_Main_Page',
                                            'Last Update Repository':'Repository_Last_Update',
                                            'Total Number of Commits':'Repository_Total_Nbr_Commits',
                                            'size':'Repository_Size',
                                            'Created at':'Repository_Created_at',
                                            'Project Id':'Repository_Project_Id',
                                            'Contributors':'Repository_Contributors',
                                            'Commits_y':'Repository_Top_Commits_Graph',                                            
})

# %% [markdown]
# ### Congrats you made it 🎉
